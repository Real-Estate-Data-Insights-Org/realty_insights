# %%
import pandas as pd

df = pd.read_csv("feature_engineered_dataset_v4.csv")

df["SaleDate"] = pd.to_datetime(df["SaleDate"])

df.head()
# Out:
#    xrCompositeLandUseID  xrBuildingTypeID  LocationStartNumber  \
# 0                     3               6.0                   77
# 1                     3               3.0                   73
# 2                     3               6.0                   61
# 3                     3               6.0                  211
# 4                     3               3.0                   18
#
#   StreetNameAndWay  xrPrimaryNeighborhoodID  LandSF  TotalFinishedArea  \
# 0      STAFFORD ST                        2  6000.0             1092.0
# 1      STAFFORD ST                        2  6000.0              936.0
# 2      STAFFORD ST                        2  6000.0             1111.0
# 3    NEWINGTON AVE                        2  5040.0             1684.0
# 4       BRISTOL ST                        2  6000.0              900.0
#
#    LivingUnits   OwnerLastName                  SaleDate  ...  \
# 0          1.0          WRIGHT 2024-07-01 00:00:00+00:00  ...
# 1          1.0         SANTANA 2022-04-26 00:00:00+00:00  ...
# 2          1.0        MARTINEZ 2023-12-22 00:00:00+00:00  ...
# 3          1.0  CAHUANA FLORES 2021-01-11 00:00:00+00:00  ...
# 4          1.0          NEGRON 2021-09-21 00:00:00+00:00  ...
#
#    TotalAppraisedValue  xrSalesValidityID  xrDeedID  AssrLandUse  \
# 0               187200                  1        10            5
# 1               192300                  1        10            5
# 2               148400                  1        10            5
# 3               197900                  1        10            5
# 4               170700                  1        10            5
#
#    WasZeroPrice  LogSalePrice  SaleYear  SaleMonth  PricePerSqft  \
# 0         False     12.464587      2024          7    237.179487
# 1         False     12.245298      2022          4    222.222222
# 2         False     11.736077      2023         12    112.511251
# 3         False     12.083911      2021          1    105.106888
# 4         False     12.144203      2021          9    208.888889
#
#    AppraisalRatio
# 0        1.383547
# 1        1.081643
# 2        0.842318
# 3        0.894391
# 4        1.101347
#
# [5 rows x 21 columns]

# %%
df["YearMonth"] = df["SaleDate"].dt.to_period("M")

monthly_prices = df.groupby("YearMonth")["SalePrice"].mean()

monthly_prices.head()
# Out:
# /var/folders/hb/0y9l2hxs61s71_hjm_mdqxz00000gn/T/ipykernel_32339/1479987693.py:1: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["YearMonth"] = df["SaleDate"].dt.to_period("M")
# YearMonth
# 2020-10    204247.390244
# 2020-11    157362.000000
# 2020-12    561375.542857
# 2021-01    214466.578947
# 2021-02    194423.151899
# Freq: M, Name: SalePrice, dtype: float64

# %%
import matplotlib.pyplot as plt

monthly_prices.plot(figsize=(10,5))

plt.title("Average Property Price Over Time")
plt.xlabel("Year-Month")
plt.ylabel("Average Sale Price")

plt.show()

# %% [markdown]
# ### Time Series Analysis Insight
#
# The time series plot shows how the average property sale price changes over time.
#
# Most months show relatively stable property prices, generally ranging between typical housing market values. However, a significant spike appears around mid-2022, where the average sale price increases sharply.
#
# This spike likely indicates the presence of an *unusually high-value property transaction* during that month, which increases the monthly average.
#
# Overall, the trend suggests that property prices remain relatively stable over time with occasional spikes caused by high-value sales. Such outliers are common in real estate datasets and should be considered when interpreting market trends.

# %% [markdown]
# Instead of mean, sometimes analysts use median for real estate because of outliers.

# %%
monthly_prices = df.groupby("YearMonth")["SalePrice"].median()

# %%
import matplotlib.pyplot as plt

monthly_prices.plot(figsize=(10,5))

plt.title("Median Property Price Over Time (Outlier-Resistant)")
plt.xlabel("Year-Month")
plt.ylabel("Median Sale Price")

plt.show()

# %% [markdown]
# The huge spike is still there even with median.
# That means the dataset has an extremely large sale price in that month, probably ~10 million.
#
# Median normally removes outliers, so if the spike still appears it means:
#
# 👉 That month likely had very few transactions
#
# 👉 One very expensive property dominates the month
#
# This is actually a valid insight, not an error.

# %% [markdown]
# ### Median-Based Time Series Insight
#
# The median-based time series plot was generated to reduce the effect of extreme outlier transactions.
#
# Although median typically minimizes the impact of very large property sales, a noticeable spike still appears around mid-2022. This suggests that the number of transactions during that month may have been very small, allowing a high-value property sale to significantly influence the monthly median.
#
# Overall, the trend shows that property prices remain relatively stable across most months, with occasional spikes caused by high-value real estate transactions.

# %%
df.sort_values(by="SalePrice", ascending=False).head(5)
# Out:
#       xrCompositeLandUseID  xrBuildingTypeID  LocationStartNumber  \
# 2490                     7              16.0                   40
# 2646                     7              16.0                   40
# 2648                     7              16.0                   40
# 2649                     7              16.0                   40
# 2650                     7              16.0                   40
#
#      StreetNameAndWay  xrPrimaryNeighborhoodID  LandSF  TotalFinishedArea  \
# 2490       WILLARD ST                      263  7000.0              880.0
# 2646       WILLARD ST                      263  7000.0              880.0
# 2648       WILLARD ST                      263  7000.0              570.0
# 2649       WILLARD ST                      263  7000.0              570.0
# 2650       WILLARD ST                      263  7000.0              670.0
#
#       LivingUnits             OwnerLastName                  SaleDate  ...  \
# 2490          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
# 2646          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
# 2648          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
# 2649          1.0                 HART4 LLC 2022-08-02 00:00:00+00:00  ...
# 2650          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
#
#       xrSalesValidityID  xrDeedID  AssrLandUse  WasZeroPrice  LogSalePrice  \
# 2490                 25        10            3         False     16.142802
# 2646                 25        10            3         False     16.142802
# 2648                 25        10            3         False     16.142802
# 2649                 25        10            3         False     16.142802
# 2650                 25        10            3         False     16.142802
#
#       SaleYear  SaleMonth  PricePerSqft  AppraisalRatio  YearMonth
# 2490      2022          8  11647.890909      172.271328    2022-08
# 2646      2022          8  11647.890909      172.271328    2022-08
# 2648      2022          8  17982.708772      221.385400    2022-08
# 2649      2022          8  17982.708772      221.385400    2022-08
# 2650      2022          8  15298.722388      189.466617    2022-08
#
# [5 rows x 22 columns]

# %% [markdown]
# What your result shows
#
# All those rows are the same property transaction:
# Address: 40 WILLARD ST
# Date: 2022-08-02
# Owner: GEB HOLDINGS NC 1031 LLC
# LogSalePrice = 16.142802
#
# Convert that log value:
# 𝑆𝑎𝑙𝑒𝑃𝑟𝑖𝑐𝑒=𝑒^16.142802≈10,200,000
#
# So this is roughly a $10.2 million property sale.
#
# Also notice something important:
# ➡ The same sale appears multiple times in the dataset
# ➡ That repeated entry inflated the monthly average/median, causing the spike.

# %% [markdown]
# ### Investigation of Price Spike
#
# To understand the spike observed in the time series plot, the dataset was filtered for the month with unusually high prices.
#
# The analysis revealed that multiple entries correspond to the same high-value transaction at **40 WILLARD ST**, sold on **2022-08-02**.
# The log sale price (16.14) corresponds to an approximate property value of **$10.2 million**.
#
# Because this transaction appears multiple times in the dataset, it significantly increases the average and median sale price for that month, creating a visible spike in the time series plot.
#
# This highlights how **duplicate high-value transactions can strongly influence aggregated statistics** in real estate datasets.

# %% [markdown]
# ### Investigation of Price Spike
#
# Further investigation of the spike in August 2022 shows that multiple records correspond to the same property located at **40 WILLARD ST**.
#
# Although the rows appear similar, they represent different units or sections of the same property transaction, as indicated by differences in total finished area. However, the **same sale price and sale date are recorded across these entries**.
#
# Because the same high-value sale is repeated across several rows, it increases the calculated monthly price statistics and creates a visible spike in the time series plot.
#
# This demonstrates how multi-unit property transactions can influence aggregated housing market statistics.

# %%
df[df["StreetNameAndWay"] == "WILLARD ST"]
# Out:
#       xrCompositeLandUseID  xrBuildingTypeID  LocationStartNumber  \
# 2444                     7              16.0                   41
# 2445                     7              16.0                   41
# 2446                     7              16.0                   37
# 2447                     7              16.0                   39
# 2448                     7              16.0                   39
# ...                    ...               ...                  ...
# 2741                     7              16.0                   40
# 2742                     7              16.0                   40
# 2743                     7              16.0                   40
# 2744                     7              16.0                   40
# 2745                     7              16.0                   40
#
#      StreetNameAndWay  xrPrimaryNeighborhoodID  LandSF  TotalFinishedArea  \
# 2444       WILLARD ST                      252  7000.0              910.0
# 2445       WILLARD ST                      252  7000.0              910.0
# 2446       WILLARD ST                      252  7000.0             1006.0
# 2447       WILLARD ST                      252  7000.0             1006.0
# 2448       WILLARD ST                      252  7000.0             1006.0
# ...               ...                      ...     ...                ...
# 2741       WILLARD ST                      263  7000.0              570.0
# 2742       WILLARD ST                      263  7000.0              860.0
# 2743       WILLARD ST                      263  7000.0              860.0
# 2744       WILLARD ST                      263  7000.0              860.0
# 2745       WILLARD ST                      263  7000.0              860.0
#
#       LivingUnits             OwnerLastName                  SaleDate  ...  \
# 2444          1.0                    BROOKS 2020-10-05 00:00:00+00:00  ...
# 2445          1.0                    BROOKS 2024-04-15 00:00:00+00:00  ...
# 2446          1.0                    GARCIA 2020-12-11 00:00:00+00:00  ...
# 2447          1.0                        LI 2023-03-27 00:00:00+00:00  ...
# 2448          1.0                  DUPLEASE 2022-01-21 00:00:00+00:00  ...
# ...           ...                       ...                       ...  ...
# 2741          1.0                 HART4 LLC 2022-08-02 00:00:00+00:00  ...
# 2742          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
# 2743          1.0                 HART4 LLC 2022-08-02 00:00:00+00:00  ...
# 2744          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
# 2745          1.0                 HART4 LLC 2022-08-02 00:00:00+00:00  ...
#
#       xrSalesValidityID  xrDeedID  AssrLandUse  WasZeroPrice  LogSalePrice  \
# 2444                  1        10            3         False     11.460590
# 2445                  1        10            3         False     11.608245
# 2446                  1        10            3         False     11.349241
# 2447                  1        10            3         False     11.440366
# 2448                  1        10            3         False     11.407576
# ...                 ...       ...          ...           ...           ...
# 2741                 25        10            3         False     16.142802
# 2742                 25        10            3         False     16.142802
# 2743                 25        10            3         False     16.142802
# 2744                 25        10            3         False     16.142802
# 2745                 25        10            3         False     16.142802
#
#       SaleYear  SaleMonth  PricePerSqft  AppraisalRatio  YearMonth
# 2444      2020         10    104.285714        1.071106    2020-10
# 2445      2024          4    120.879121        1.241535    2024-04
# 2446      2020         12     84.393638        0.948603    2020-12
# 2447      2023          3     92.445328        1.027624    2023-03
# 2448      2022          1     89.463221        1.045296    2022-01
# ...        ...        ...           ...             ...        ...
# 2741      2022          8  17982.708772      221.385400    2022-08
# 2742      2022          8  11918.772093      173.144324    2022-08
# 2743      2022          8  11918.772093      173.144324    2022-08
# 2744      2022          8  11918.772093      173.144324    2022-08
# 2745      2022          8  11918.772093      173.144324    2022-08
#
# [279 rows x 22 columns]

# %%
df.sort_values(by="SalePrice", ascending=False).head(5)
# Out:
#       xrCompositeLandUseID  xrBuildingTypeID  LocationStartNumber  \
# 2490                     7              16.0                   40
# 2646                     7              16.0                   40
# 2648                     7              16.0                   40
# 2649                     7              16.0                   40
# 2650                     7              16.0                   40
#
#      StreetNameAndWay  xrPrimaryNeighborhoodID  LandSF  TotalFinishedArea  \
# 2490       WILLARD ST                      263  7000.0              880.0
# 2646       WILLARD ST                      263  7000.0              880.0
# 2648       WILLARD ST                      263  7000.0              570.0
# 2649       WILLARD ST                      263  7000.0              570.0
# 2650       WILLARD ST                      263  7000.0              670.0
#
#       LivingUnits             OwnerLastName                  SaleDate  ...  \
# 2490          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
# 2646          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
# 2648          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
# 2649          1.0                 HART4 LLC 2022-08-02 00:00:00+00:00  ...
# 2650          1.0  GEB HOLDINGS NC 1031 LLC 2022-08-02 00:00:00+00:00  ...
#
#       xrSalesValidityID  xrDeedID  AssrLandUse  WasZeroPrice  LogSalePrice  \
# 2490                 25        10            3         False     16.142802
# 2646                 25        10            3         False     16.142802
# 2648                 25        10            3         False     16.142802
# 2649                 25        10            3         False     16.142802
# 2650                 25        10            3         False     16.142802
#
#       SaleYear  SaleMonth  PricePerSqft  AppraisalRatio  YearMonth
# 2490      2022          8  11647.890909      172.271328    2022-08
# 2646      2022          8  11647.890909      172.271328    2022-08
# 2648      2022          8  17982.708772      221.385400    2022-08
# 2649      2022          8  17982.708772      221.385400    2022-08
# 2650      2022          8  15298.722388      189.466617    2022-08
#
# [5 rows x 22 columns]

# %% [markdown]
# Notice these are identical:
#
# same SaleDate
#
# same LogSalePrice
#
# same SaleYear / SaleMonth
#
# same LandSF
#
# Only unit area / owner record differs.
#
# So the dataset probably records units within the same property sale.
#
# Correct Interpretation:
# It is one large property transaction recorded across multiple units.
# This still inflates the monthly price statistic, because the same sale price is repeated multiple times.

# %%
#we must habdle this before visualisations

# %%
sales_unique = df.drop_duplicates(
    subset=["StreetNameAndWay", "LocationStartNumber", "SaleDate", "LogSalePrice"]
)

print("Original rows:", len(df))
print("Unique sales:", len(sales_unique))
# Out:
# Original rows: 4566
# Unique sales: 3935

# %% [markdown]
# So there were repeated sales records: 4566−3935=631

# %% [markdown]
# ### Handling Repeated Property Sale Records
#
# Some property transactions appear multiple times in the dataset because individual units or sections of a property are recorded separately while sharing the same sale information.
#
# To avoid inflating the time-series statistics, duplicate sale transactions were removed using a combination of property address and sale date.
#
# After removing repeated transaction entries:
#
# - Original dataset size: **4566 rows**
# - Unique property sales: **3935 rows**
#
# This ensures that each property sale contributes only once when analyzing housing market trends over time.

# %%
monthly_prices = sales_unique.groupby("YearMonth")["SalePrice"].median()

# %%
import matplotlib.pyplot as plt

monthly_prices.plot(figsize=(10,5))

plt.title("Median Property Price Over Time (Cleaned Sales)")
plt.xlabel("Year-Month")
plt.ylabel("Median Sale Price")

plt.show()

# %% [markdown]
# ### Time Series Insight
#
# The median monthly property price shows a gradual upward trend from 2021 to 2024, indicating a steady increase in housing values over time.
#
# Monthly fluctuations are expected in real estate markets due to variations in property type, size, and location of transactions.
#
# After removing repeated transaction entries, the time series no longer shows extreme artificial spikes, providing a more reliable representation of market behavior.
#
# Overall, the trend suggests moderate growth in property prices with typical short-term variations.

# %%
sales_unique = df.drop_duplicates(
    subset=["StreetNameAndWay", "LocationStartNumber", "SaleDate", "LogSalePrice"]
)
sales_unique.to_csv("cleaned_property_sales_timeseries.csv", index=False)

# %% [markdown]
# # Smoothing

# %%
monthly_prices = sales_unique.groupby("YearMonth")["SalePrice"].median()

# %%
monthly_prices_ma = monthly_prices.rolling(window=3).mean()

# %%
monthly_prices.index = monthly_prices.index.to_timestamp()
monthly_prices_ma.index = monthly_prices_ma.index.to_timestamp()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.plot(monthly_prices, label="Original Median Price")
plt.plot(monthly_prices_ma, label="3-Month Moving Average", linewidth=3)

plt.title("Smoothed Property Price Trend")
plt.xlabel("Year-Month")
plt.ylabel("Median Sale Price")

plt.legend()
plt.show()

# %% [markdown]
# Smoothing Insight
#
# a) Overall trend:
# The smoothed (3-month moving average) line shows a clear upward trend from 2021 to 2024, meaning property prices are gradually increasing over time.
#
# b) Short-term fluctuations:
# The blue line (original prices) has many spikes, but the moving average removes noise and shows the true market trend.
#
# c) Strong growth after 2023:
# From mid-2023 onwards, the smoothed line rises more sharply, indicating stronger price appreciation in the housing market.
#
# d) Market volatility:
# Some months show sudden drops or spikes, likely due to different property sizes, locations, or high-value sales, which is common in real estate datasets.
#
# e) Why smoothing helps:
# The moving average helps analysts identify the underlying market trend without being misled by monthly fluctuations.
#
# In the end all that you need to know is:
# a) Prices show a steady upward trend (2021 → 2024)
# b) Monthly spikes are noise from individual property sales
# c) The 3-month moving average reveals the real market trend clearly.

# %% [markdown]
# ### Final Step: Trend Line (Simple Forecast Direction)
#
# Add a trend line using regression.

# %%
import numpy as np

x = np.arange(len(monthly_prices))
y = monthly_prices.values

coeffs = np.polyfit(x, y, 1)
trend = np.poly1d(coeffs)

plt.figure(figsize=(10,5))

plt.plot(monthly_prices.index, y, label="Median Price")
plt.plot(monthly_prices.index, trend(x), label="Trend Line", linewidth=3)

plt.title("Property Price Trend Over Time")
plt.xlabel("Year-Month")
plt.ylabel("Median Sale Price")

plt.legend()
plt.show()

# %% [markdown]
# Trend Line Insight
#
# a) Upward market trend
# The regression trend line clearly shows that property prices have steadily increased from 2021 to 2024.
#
# b) Underlying growth
# Even though monthly prices fluctuate due to individual transactions, the trend line confirms long-term appreciation in the housing market.
#
# c) Market volatility vs trend
# The blue line shows short-term variations caused by property size, location, or high-value sales, while the trend line captures the overall market direction.
#
# d) Business meaning
# This indicates a growing real estate market, suggesting increasing property demand or rising valuation over the observed period.

# %% [markdown]
# Time Series section is COMPLETE.
#
# You will have:
#
# 1️⃣ Raw time series
# 2️⃣ Median time series
# 3️⃣ Outlier investigation
# 4️⃣ Cleaned time series
# 5️⃣ Moving average smoothing
# 6️⃣ Trend analysis
