# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("feature_engineered_dataset.csv")

print("Dataset Shape:", df.shape)

df.head()
# Out:
# Dataset Shape: (4566, 21)
#    xrCompositeLandUseID  xrBuildingTypeID  LocationStartNumber  \
# 0                     3               6.0                   77
# 1                     3               3.0                   73
# 2                     3               6.0                   61
# 3                     3               6.0                  211
# 4                     3               3.0                   18
#
#   StreetNameAndWay  xrPrimaryNeighborhoodID  LandSF  TotalFinishedArea  \
# 0      STAFFORD ST                        2  6000.0             1092.0
# 1      STAFFORD ST                        2  6000.0              936.0
# 2      STAFFORD ST                        2  6000.0             1111.0
# 3    NEWINGTON AVE                        2  5040.0             1684.0
# 4       BRISTOL ST                        2  6000.0              900.0
#
#    LivingUnits   OwnerLastName                   SaleDate  ...  \
# 0          1.0          WRIGHT  2024-07-01 00:00:00+00:00  ...
# ...

# %%
# Feature and Target Selection

# Target variable
y = df['SalePrice']

# Remove target and leakage/unnecessary columns
X = df.drop(columns=[
    'SalePrice',
    'OwnerLastName',
    'StreetNameAndWay',
    'SaleDate',
    'LogSalePrice',
    'PricePerSqft',
    'AppraisalRatio'
], errors='ignore')

print("Feature Matrix Shape:", X.shape)
print("Target Shape:", y.shape)

print("\nFeatures used:")
print(X.columns)
# Out:
# Feature Matrix Shape: (4566, 14)
# Target Shape: (4566,)
#
# Features used:
# Index(['xrCompositeLandUseID', 'xrBuildingTypeID', 'LocationStartNumber',
#        'xrPrimaryNeighborhoodID', 'LandSF', 'TotalFinishedArea', 'LivingUnits',
#        'TotalAppraisedValue', 'xrSalesValidityID', 'xrDeedID', 'AssrLandUse',
#        'WasZeroPrice', 'SaleYear', 'SaleMonth'],
#       dtype='object')

# %%
# Encode categorical variables using One-Hot Encoding

X_encoded = pd.get_dummies(X, drop_first=True)

print("Encoded Feature Shape:", X_encoded.shape)

X_encoded.head()
# Out:
# Encoded Feature Shape: (4566, 14)
#    xrCompositeLandUseID  xrBuildingTypeID  LocationStartNumber  \
# 0                     3               6.0                   77
# 1                     3               3.0                   73
# 2                     3               6.0                   61
# 3                     3               6.0                  211
# 4                     3               3.0                   18
#
#    xrPrimaryNeighborhoodID  LandSF  TotalFinishedArea  LivingUnits  \
# 0                        2  6000.0             1092.0          1.0
# 1                        2  6000.0              936.0          1.0
# 2                        2  6000.0             1111.0          1.0
# 3                        2  5040.0             1684.0          1.0
# 4                        2  6000.0              900.0          1.0
#
#    TotalAppraisedValue  xrSalesValidityID  xrDeedID  AssrLandUse  \
# 0               187200                  1        10            5
# ...

# %%
# Train-Test Split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    random_state=42
)

print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)
# Out:
# Training set shape: (3652, 14)
# Testing set shape: (914, 14)

# %%
# Train Gradient Boosting Regressor

from sklearn.ensemble import GradientBoostingRegressor

# Initialize model
gbr = GradientBoostingRegressor(random_state=42)

# Train model
gbr.fit(X_train, y_train)

print("Gradient Boosting model trained successfully!")
# Out:
# Gradient Boosting model trained successfully!

# %%
# Predict using Gradient Boosting model

gbr_pred = gbr.predict(X_test)

print("Predictions completed!")

print("\nFirst 10 Predictions:")
print(gbr_pred[:10])
# Out:
# Predictions completed!
#
# First 10 Predictions:
# [ 228911.34438724  175182.14181016  154407.45933147  179740.26358027
#   309850.53103692  244434.71046376 9664839.07409817  183896.67508399
#   257216.75305802  102994.06227488]

# %%
# Evaluate Gradient Boosting model

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, gbr_pred)
rmse = np.sqrt(mean_squared_error(y_test, gbr_pred))
r2 = r2_score(y_test, gbr_pred)

print("Gradient Boosting Model Performance")
print("MAE:", mae)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# Gradient Boosting Model Performance
# MAE: 110038.39849051506
# RMSE: 229246.69860276196
# R2 Score: 0.9894344583933202

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.scatter(y_test, gbr_pred)

plt.xlabel("Actual Sale Price")
plt.ylabel("Predicted Sale Price")
plt.title("Actual vs Predicted Sale Price (Gradient Boosting)")

plt.show()

# %%
# Box Plot for Sale Price

import matplotlib.pyplot as plt

plt.figure()

plt.boxplot(df['SalePrice'])

plt.title("Box Plot of Sale Price")
plt.ylabel("Sale Price")

plt.show()

# %% [markdown]
# ### Insight
#
# Gradient Boosting Regressor was implemented as an additional ensemble learning model.
# The model achieved an R² score of approximately 0.989, indicating that it explains nearly 99% of the variance in property sale prices.
#
# Gradient Boosting works by sequentially building decision trees, where each new tree corrects the errors of the previous trees.
# This approach allows the model to capture complex nonlinear relationships in the housing dataset.
#
# Compared to other models tested in this project, Gradient Boosting showed one of the best predictive performances,
# making it highly suitable for real estate price prediction.
